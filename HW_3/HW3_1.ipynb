# %% [markdown]
# <a href="https://colab.research.google.com/github/kaarthikalagappan/ai_course_projects/blob/master/HW3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_random_data(w, b, mu, sigma, m):
    data = np.zeros(shape=(m, 2))
    labels = np.zeros(shape=(m, 1))
    # print(labels)
    for i in range(m):
        rnd = random.random()
        if rnd < 0.5:
            c = 0
        else:
            c = 1
        x_1 = np.random.uniform(0, 1)
        n = np.random.normal(mu, sigma)
        x_2 = w * x_1 + b + (-1)**c * n
        # data[i] = ([x_1, x_2])
        # np.append(data, [x_1, x_2])
        data[i] = [x_1, x_2]
        labels[i] = c
    return data, labels

# %%
def display_random_data(data, labels):
    x, y = data.T
    for i in range(x.size):
        if labels[i] == 1:
            color = "r."
        else:
            color = "b."
        plt.plot(x[i], y[i], color)

# %%
data, labels = get_random_data(2, 3, .2, .15, 1000)
display_random_data(data, labels)

training_size = int(labels.size * .8)
test_size = labels.size - training_size
test_indicies = labels.size - test_size

training_data = data[:training_size]
training_labels = labels[:training_size]

test_data = data[test_indicies:]
test_labels = labels[test_indicies:]
